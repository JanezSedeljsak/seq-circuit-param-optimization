# %%
from algorithms import *
from evaluators import *
import matplotlib.pyplot as plt
import numpy as np
import warnings

np.random.seed(42)
warnings.filterwarnings("ignore")

# %%
print(ExampleEvaluator().get_params())
ExampleEvaluator().simulate(algo='baseline')
# Out:
# {'alpha1': 34.73, 'alpha2': 49.36, 'alpha3': 32.73, 'alpha4': 49.54, 'delta1': 1.93, 'delta2': 0.69, 'Kd': 10.44, 'n': 4.35}

# %% [markdown]
# ## Optimizations with hyperparameter search

# %% [markdown]
# #### Grey Wolf Optimizer

# %%
gw_param_options = {
    'population': [10, 15]
}

gw_hyper = HyperSearch(GreyWolfOptimizer, GoalEvaluator).execute(**gw_param_options)
print("Hyper parameters", gw_hyper.best_params, "Best seed", gw_hyper.best_seed)
# Out:
# Hyper search start [steps=8]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# Converged after 3
# Hyper parameters {'population': 10} Best seed 42

# %%
gw_evaluator = gw_hyper.optimize_parameters(gw_hyper.best_params['population'], 100)

print("Evaluation", gw_evaluator.evaluate())
print("Best params", gw_evaluator.get_params())
gw_evaluator.simulate()
# Out:
# Generation 1/20
# Best Fitness: 1500000
# Generation 2/20
# Best Fitness: 1300000
# Generation 3/20
# Best Fitness: 15060.229741780902
# Generation 4/20
# Best Fitness: 282.05274467023867
# Generation 5/20
# Best Fitness: 9.060325551950065
# Generation 6/20
# Best Fitness: 1400000
# Generation 7/20
# Best Fitness: 25.102224005540293
# Generation 8/20
# Best Fitness: 236.41421744249908
# Generation 9/20
# Best Fitness: 0.8900028956142604
# Generation 10/20
# Best Fitness: 2.3136870823025584
# Generation 11/20
# Best Fitness: 0.6032881370680907
# Generation 12/20
# Best Fitness: 0.03714928146871518
# Generation 13/20
# Best Fitness: 0.021734591240915757
# Generation 14/20
# Best Fitness: 0.7798794185086614
# Generation 15/20
# Best Fitness: 0.07029945781501351
# Generation 16/20
# Best Fitness: 10.71264909216398
# Generation 17/20
# Best Fitness: 0.5320161382133803
# Generation 18/20
# Best Fitness: 1.845718919831751
# Generation 19/20
# Best Fitness: 20.74989850270221
# Generation 20/20
# Best Fitness: 13.835727948527413
# Best Fitness: 0.021734591240915757
# Evaluation -0.021734591240915757
# Best params {'alpha1': 50.0, 'alpha2': 50.0, 'alpha3': 50.0, 'alpha4': 50.0, 'delta1': 4.081462991255607, 'delta2': 3.38321373738478, 'Kd': 0.8577138489461968, 'n': 5.0}

# %% [markdown]
# #### Whale Optimization Algorithm

# %%
woa_param_options = {
    'generations': 15,
    'mutation_strength': np.linspace(0.1, 0.4, 3),
    'population': [10, 15]
}

woa_hyper = HyperSearch(WhaleOptimizationAlgorithm, GoalEvaluator).execute(**woa_param_options)
print("Hyper parameters", woa_hyper.best_params, "Best seed", woa_hyper.best_seed)
# Out:
# Hyper search start [steps=24]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/6 [00:00<?, ?it/s]
#
# Generation 182/200
# Best Fitness: 703.0081462491997
# Generation 183/200
# Best Fitness: 1061.416471597168
# Generation 184/200
# Best Fitness: 39.41014183793668
# Generation 185/200
# Best Fitness: 161.81827042526822
# Generation 186/200
# Best Fitness: 1.6028087914915823
# Generation 187/200
# Best Fitness: 1.1421132558034828
# Generation 188/200
# Best Fitness: 4.447124047185546
# Generation 189/200
# Best Fitness: 13.87557041840345
# Generation 190/200
# Best Fitness: 276.5184974925724
# Generation 191/200
# Best Fitness: 39.466978933672046
# Generation 192/200
# Best Fitness: 1606.22920778241
# Generation 193/200
# Best Fitness: 896.8151019912104
# Generation 194/200
# Best Fitness: 1042.4453516123674
# Generation 195/200
# Best Fitness: 13940.48227606729
# Generation 196/200
# Best Fitness: 466.6547904404685
# Generation 197/200
# Best Fitness: 654.9618542662231
# Generation 198/200
# Best Fitness: 81.01186667929693
# Generation 199/200
# Best Fitness: 104.97898004900394
# Generation 200/200
# Best Fitness: 1.4529969975980634
# Best Fitness: 166.3911028119509
# Evaluation -166.3911028119509
# Best params {'alpha1': 32.46806059890831, 'alpha2': 26.80025189782559, 'alpha3': 25.327515498516767, 'alpha4': 25.13127780451237, 'delta1': 1.0742326542973395, 'delta2': 0.6650286827565359, 'Kd': 11.041621585887713, 'n': 5.0}

# %% [markdown]
# #### Ant Colony Optimization

# %%
ant_param_options = {
    'generations': 10,
    'population': [15, 20],
    'rho': np.linspace(0.1, 0.3, 5),
    'elite_percentage': [0.1, 0.2]
}

#ant_hyper = HyperSearch(AntColonyOptimization, GoalEvaluator).execute(**ant_param_options)
#print("Hyper parameters", ant_hyper.best_params, "Best seed", ant_hyper.best_seed)

# %%
#ant_evaluator = ant_hyper.optimize_parameters(ant_hyper.best_params['population'], 50)

#print("Evaluation", ant_evaluator.evaluate())
#print("Best params", ant_evaluator.get_params())
#ant_evaluator.simulate()

# %% [markdown]
# #### Genetic Algorithm

# %%
ga_param_options = {
    'generations': 10,
    'population': [15, 20],
    'mutation_rate': np.linspace(0.05, 0.5, 4),
    'elite_percentage': [0.15]
}

ga_hyper = HyperSearch(GeneticAlgorithm, GoalEvaluator).execute(**ga_param_options)
print("Hyper parameters", ga_hyper.best_params, "Best seed", ga_hyper.best_seed)
# Out:
# Hyper search start [steps=32]
#   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
#   0%|          | 0/8 [00:00<?, ?it/s]
# Hyper parameters {'elite_percentage': 0.15, 'mutation_rate': 0.5, 'population': 20} Best seed 555

# %%
ga_evaluator = ga_hyper.optimize_parameters(50, 100, seed=12)

print("Evaluation", ga_evaluator.evaluate())
print("Best params", ga_evaluator.get_params())
ga_evaluator.simulate()
# Out:
# [0] Update best with -1300000.00000
# [4] Update best with -1000000.00000
# [21] Update best with -654564.57743
# [25] Update best with -0.00894
# Evaluation -0.008940559381597712
# Best params {'alpha1': 5.168931676215046, 'alpha2': 33.47689434663473, 'alpha3': 25.819007017158995, 'alpha4': 17.49217691007206, 'delta1': 29.66916950866765, 'delta2': 1.9394517901717823, 'Kd': 0.1744525418130607, 'n': 3.8371206598881398}
