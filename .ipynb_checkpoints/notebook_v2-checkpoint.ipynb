# %%
from algorithms import *
from evaluators import *
import matplotlib.pyplot as plt
import numpy as np
import warnings

np.random.seed(42)
warnings.filterwarnings("ignore")

# %%
print(ExampleEvaluator().get_params())
ExampleEvaluator().simulate(algo='baseline')
# Out:
# {'alpha1': 34.73, 'alpha2': 49.36, 'alpha3': 32.73, 'alpha4': 49.54, 'delta1': 1.93, 'delta2': 0.69, 'Kd': 10.44, 'n': 4.35}

# %%
best_params = GreyWolfOptimizer(GoalEvaluator, is_export=True).optimize_parameters(10, 10)
evaluation = GoalEvaluator(**best_params)
print(evaluation.evaluate())
# Out:
# Generation 1/10
# Best Fitness: 15000
# Generation 2/10
# Best Fitness: 13000
# Generation 3/10
# Best Fitness: 6847.3473040341405
# Generation 4/10
# Best Fitness: 0.04968669225861722
# Generation 5/10
# Best Fitness: 0.004028699073083849
# Generation 6/10
# Best Fitness: 0.0006273040816233307
# Generation 7/10
# Best Fitness: 0.00022285652855390765
# Generation 8/10
# Best Fitness: 0.0006979438523292049
# Generation 9/10
# Best Fitness: 0.000522625394507839
# Generation 10/10
# Best Fitness: 0.0038230182003965965
# Best Fitness: 0.0038230182003965965
# -0.04075965276170254

# %%
print(evaluation.get_params())
print(evaluation.evaluate())
evaluation.simulate()
# Out:
# {'alpha1': 50.0, 'alpha2': 23.993447438511115, 'alpha3': 48.026660659755244, 'alpha4': 48.74940300352167, 'delta1': 0.9221259525434861, 'delta2': 1.6734679604162677, 'Kd': 18.055854711389173, 'n': 14.223197446859754}
# -0.04075965276170254

# %%
from joblib import Parallel, delayed

def optimize_params(optimizer):
    return optimizer.optimize_parameters(25, 100)

optimizers = [
    AntColonyOptimization(GoalEvaluator),
    WhaleOptimizationAlgorithm(GoalEvaluator),
    GeneticAlgorithm(GoalEvaluator),
    GreyWolfOptimizer(GoalEvaluator)
]

results = Parallel(n_jobs=len(optimizers))(
    delayed(optimize_params)(optimizer) for optimizer in optimizers
)

print(results)
ant, whale, genetic, wolf = results
# Out:
# [{'alpha1': 41.546015143461844, 'alpha2': 43.50237206520988, 'alpha3': 38.701313384783575, 'alpha4': 45.91724344564031, 'delta1': 0.1983998283451715, 'delta2': 0.7033079882398062, 'Kd': 59.691468643036934, 'n': 3.8374892076716494}, {'alpha1': 0.011037735323010254, 'alpha2': 0.022156240598779697, 'alpha3': 0.011037735323010254, 'alpha4': 0.011037735323010254, 'delta1': 0.011037735323010254, 'delta2': 0.011037735323010254, 'Kd': 0.011037735323010254, 'n': 0.7799156444279155}, {'alpha1': 7.454342505990256, 'alpha2': 6.277822382082313, 'alpha3': 47.23628314608944, 'alpha4': 46.26278631455191, 'delta1': 60.61304863119027, 'delta2': 46.723357113625184, 'Kd': 36.64541381742423, 'n': 4.750641487447179}, {'alpha1': 29.781499515918437, 'alpha2': 39.729738262939975, 'alpha3': 39.729738262939975, 'alpha4': 39.729738262939975, 'delta1': 39.729738262939975, 'delta2': 0.03637099276398854, 'Kd': 39.729738262939975, 'n': 9.518302387103041}]

# %%
evaluation = GoalEvaluator(**ant)
print(evaluation.get_params())
print(evaluation.evaluate())
evaluation.simulate(algo='ant')
# Out:
# {'alpha1': 41.546015143461844, 'alpha2': 43.50237206520988, 'alpha3': 38.701313384783575, 'alpha4': 45.91724344564031, 'delta1': 0.1983998283451715, 'delta2': 0.7033079882398062, 'Kd': 59.691468643036934, 'n': 3.8374892076716494}
# -409.27254752230715

# %%
evaluation = GoalEvaluator(**whale)
print(evaluation.get_params())
print(evaluation.evaluate())
evaluation.simulate(algo='whale')
# Out:
# {'alpha1': 0.011037735323010254, 'alpha2': 0.022156240598779697, 'alpha3': 0.011037735323010254, 'alpha4': 0.011037735323010254, 'delta1': 0.011037735323010254, 'delta2': 0.011037735323010254, 'Kd': 0.011037735323010254, 'n': 0.7799156444279155}
# -14000

# %%
evaluation = GoalEvaluator(**wolf)
print(evaluation.get_params())
print(evaluation.evaluate())
evaluation.simulate(algo='wolf')
# Out:
# {'alpha1': 29.781499515918437, 'alpha2': 39.729738262939975, 'alpha3': 39.729738262939975, 'alpha4': 39.729738262939975, 'delta1': 39.729738262939975, 'delta2': 0.03637099276398854, 'Kd': 39.729738262939975, 'n': 9.518302387103041}
# -3767.31272056205

# %%
evaluation = GoalEvaluator(**genetic)
print(evaluation.get_params())
print(evaluation.evaluate())
evaluation.simulate(algo='genetic')
# Out:
# {'alpha1': 7.454342505990256, 'alpha2': 6.277822382082313, 'alpha3': 47.23628314608944, 'alpha4': 46.26278631455191, 'delta1': 60.61304863119027, 'delta2': 46.723357113625184, 'Kd': 36.64541381742423, 'n': 4.750641487447179}
# -15000
