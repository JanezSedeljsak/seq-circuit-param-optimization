# %%
from algorithms import *
from evaluators import *
import matplotlib.pyplot as plt
import numpy as np
import warnings

np.random.seed(42)
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Baseline

# %%
print(ExampleEvaluator().get_params())
ExampleEvaluator().simulate(algo='baseline')
# Out:
# {'alpha1': 34.73, 'alpha2': 49.36, 'alpha3': 32.73, 'alpha4': 49.54, 'delta1': 1.93, 'delta2': 0.69, 'Kd': 10.44, 'n': 4.35}

# %% [markdown]
# ## Genetic algorithm

# %%
best_params = GeneticAlgorithm(FreqEvaluator).optimize_parameters(15, 40)
evaluation = FreqEvaluator(**best_params)

print(evaluation.get_params())
print(evaluation.evaluate())
evaluation.simulate(out='./genetic_freq.png', algo='genetic')
# Out:
# [0] Update best with 85.91483
# [11] Update best with 103.89804
# [22] Update best with 110.26236
# [28] Update best with 111.10448
# [32] Update best with 120.46085
# {'alpha1': 32.19284358338062, 'alpha2': 50.0, 'alpha3': 35.402124188796385, 'alpha4': 50.0, 'delta1': 2.5265995174050895, 'delta2': 0.69, 'Kd': 1.0027358122363825, 'n': 4.694228789320289}
# 120.46084716012967

# %%
best_params = GeneticAlgorithm(ClockEvaluator).optimize_parameters(15, 40)
evaluation = ClockEvaluator(**best_params)

print(evaluation.get_params())
print(evaluation.evaluate())
evaluation.simulate(out='./genetic_clock.png', algo='genetic')
# Out:
# [0] Update best with -158908907.99927
# [4] Update best with -149306341.02182
# [6] Update best with -146949931.63568
# [10] Update best with -146646093.38448
# [11] Update best with -145296016.33971
# [12] Update best with -144316770.27790
# [15] Update best with -142293608.18673
# [16] Update best with -102711061.27543
# [20] Update best with -102355471.78598
# [21] Update best with -100348241.13535
# [23] Update best with -99334751.84968
# [28] Update best with -99255658.68419
# [29] Update best with -96114984.63042
# [31] Update best with -95982260.71698
# {'alpha1': 10.00114163169205, 'alpha2': 50.0, 'alpha3': 44.60356372723517, 'alpha4': 45.581189557712435, 'delta1': 27.532500601727005, 'delta2': 0.8303001514887693, 'Kd': 0.01, 'n': 1.5176893792713297}
# -95982260.71697725

# %% [markdown]
# ## Ant colony optimization algorithm

# %%
best_params = AntColonyOptimization(FreqEvaluator).optimize_parameters(10, 30)
evaluation = FreqEvaluator(**best_params)

print(evaluation.get_params())
print(evaluation.evaluate())
evaluation.simulate(out='./ant_freq.png', algo='ant colony')
# Out:
# [0] Update best with 80.52851
# [1] Update best with 91.20807
# [2] Update best with 93.47699
# [8] Update best with 107.84621
# [20] Update best with 108.69384
# [21] Update best with 125.33120
# {'alpha1': 34.35314922887944, 'alpha2': 48.28194822205381, 'alpha3': 33.73712427295257, 'alpha4': 49.72924720752084, 'delta1': 3.5414856414662186, 'delta2': 1.8126245885950971, 'Kd': 8.580503059802401, 'n': 2.4669448278835935}
# 125.33120301358106

# %%
best_params = AntColonyOptimization(ClockEvaluator).optimize_parameters(10, 30)
evaluation = ClockEvaluator(**best_params)

print(evaluation.get_params())
print(evaluation.evaluate())
evaluation.simulate(out='./ant_clock.png', algo='ant colony')
# Out:
# [0] Update best with -107836736.27210
# [2] Update best with -97372865.94757
# {'alpha1': 35.75108539876129, 'alpha2': 48.16103025293218, 'alpha3': 33.03375172793731, 'alpha4': 49.31885215028968, 'delta1': 3.4352875266776133, 'delta2': 0.33046243931082886, 'Kd': 12.259380389657814, 'n': 1.850728838036265}
# -97372865.94756822

# %% [markdown]
# ## Grey wolf optimizer

# %%
best_params = GreyWolfOptimizer(FreqEvaluator).optimize_parameters(15, 15)
evaluation = FreqEvaluator(**best_params)

print(evaluation.get_params())
print(evaluation.evaluate())
evaluation.simulate(out='./wolf_freq.png', algo='grey wolf optimizer')
# Out:
# Generation 1/15
# Best Fitness: 0
# Generation 2/15
# Best Fitness: -12.700908092375219
# Generation 3/15
# Best Fitness: -13.81150838763006
# Generation 4/15
# Best Fitness: -12.696027648988533
# Generation 5/15
# Best Fitness: -12.886843113342124
# Generation 6/15
# Best Fitness: -14.387675249419381
# Generation 7/15
# Best Fitness: -15.648358605800098
# Generation 8/15
# Best Fitness: -26.75560801064075
# Generation 9/15
# Best Fitness: -105.85691810146389
# Generation 10/15
# Best Fitness: -103.43445980531584
# Generation 11/15
# Best Fitness: -104.48383719871734
# Generation 12/15
# Best Fitness: -106.75263037130142
# Generation 13/15
# Best Fitness: -107.53488438219529
# Generation 14/15
# Best Fitness: -105.88196448571867
# Generation 15/15
# Best Fitness: -104.63777833310542
# Best Fitness: -104.63777833310542
# {'alpha1': 0.09042478868854213, 'alpha2': 0.09042478868854213, 'alpha3': 50.0, 'alpha4': 0.09042478868854213, 'delta1': 0.09042478868854213, 'delta2': 0.09042478868854213, 'Kd': 50.0, 'n': 0.2448318428750197}
# 104.09447840574367

# %%
best_params = GreyWolfOptimizer(ClockEvaluator).optimize_parameters(15, 15)
evaluation = ClockEvaluator(**best_params)

print(evaluation.get_params())
print(evaluation.evaluate())
evaluation.simulate(out='./wolf_clock.png', algo='grey wolf optimizer')
# Out:
# Generation 1/15
# Best Fitness: 10000000000.0
# Generation 2/15
# Best Fitness: 10000000000.0
# Generation 3/15
# Best Fitness: 10000000000.0
# Generation 4/15
# Best Fitness: 139155324.84224343
# Generation 5/15
# Best Fitness: 103496436.44729844
# Generation 6/15
# Best Fitness: 104307937.11585511
# Generation 7/15
# Best Fitness: 125428494.48462225
# Generation 8/15
# Best Fitness: 112408434.1208713
# Generation 9/15
# Best Fitness: 109155273.72883376
# Generation 10/15
# Best Fitness: 104078430.35377766
# Generation 11/15
# Best Fitness: 98724471.86626436
# Generation 12/15
# Best Fitness: 103287257.96770865
# Generation 13/15
# Best Fitness: 105521690.27601966
# Generation 14/15
# Best Fitness: 100083468.24958582
# Generation 15/15
# Best Fitness: 99126929.57597636
# Best Fitness: 99126929.57597636
# {'alpha1': 50.0, 'alpha2': 20.970401004293343, 'alpha3': 3.629500752032457, 'alpha4': 21.208022049092296, 'delta1': 0.06126642115276985, 'delta2': 0.06126642115276985, 'Kd': 0.06126642115276985, 'n': 1.4439713114804154}
# -98146871.22790837

# %% [markdown]
# ## Whale optimization algorithm

# %%
best_params = WhaleOptimizationAlgorithm(FreqEvaluator).optimize_parameters(15, 15)
evaluation = FreqEvaluator(**best_params)

print(evaluation.get_params())
print(evaluation.evaluate())
evaluation.simulate(out='./whale_freq.png', algo='whale optimization')
# Out:
# Generation 1/15
# Best Fitness: 0
# Generation 2/15
# Best Fitness: -16.25081557827626
# Generation 3/15
# Best Fitness: -33.74691151327637
# Generation 4/15
# Best Fitness: 0
# Generation 5/15
# Best Fitness: -59.40046559828024
# Generation 6/15
# Best Fitness: -10.131277084635165
# Generation 7/15
# Best Fitness: -10.028390738467683
# Generation 8/15
# Best Fitness: 0
# Generation 9/15
# Best Fitness: -12.084321402415416
# Generation 10/15
# Best Fitness: -18.139661448938686
# Generation 11/15
# Best Fitness: -9.028422126417034
# Generation 12/15
# Best Fitness: -18.236686982278258
# Generation 13/15
# Best Fitness: -9.101521947657272
# Generation 14/15
# Best Fitness: -9.137033977155138
# Generation 15/15
# Best Fitness: -18.25723694427231
# Best Fitness: -18.25723694427231
# {'alpha1': 1.0578251081925585, 'alpha2': 0.1143459420161919, 'alpha3': 3.2802452031987857, 'alpha4': 5.433050803136086, 'delta1': 3.3152812957337843, 'delta2': 0.12815157441940053, 'Kd': 0.1181831999609189, 'n': 0.18776705247285586}
# 18.25723694427231

# %%
best_params = WhaleOptimizationAlgorithm(ClockEvaluator).optimize_parameters(15, 15)
evaluation = ClockEvaluator(**best_params)

print(evaluation.get_params())
print(evaluation.evaluate())
evaluation.simulate(out='./wolf_clock.png', algo='whale optimization')
# Out:
# Generation 1/15
# Best Fitness: 153143849.6006943
# Generation 2/15
# Best Fitness: 153143849.6006943
# Generation 3/15
# Best Fitness: 149110100.7310456
# Generation 4/15
# Best Fitness: 149053961.73049372
# Generation 5/15
# Best Fitness: 110045025.99142002
# Generation 6/15
# Best Fitness: 112840019.29279447
# Generation 7/15
# Best Fitness: 102620834.64237612
# Generation 8/15
# Best Fitness: 101161827.05465278
# Generation 9/15
# Best Fitness: 98803946.4839492
# Generation 10/15
# Best Fitness: 97509435.16664861
# Generation 11/15
# Best Fitness: 97499503.41756605
# Generation 12/15
# Best Fitness: 97100583.7158166
# Generation 13/15
# Best Fitness: 96664783.55743459
# Generation 14/15
# Best Fitness: 96440535.89524406
# Generation 15/15
# Best Fitness: 96394987.90456304
# Best Fitness: 96394987.90456304
# {'alpha1': 25.49735219752315, 'alpha2': 25.497352197479557, 'alpha3': 29.97619807541736, 'alpha4': 13.993075635577, 'delta1': 6.408612131354454, 'delta2': 0.23107529551523273, 'Kd': 25.497352197480172, 'n': 0.23107529406711255}
# -96394987.90456304

# %% [markdown]
# ## Joined evaluation with ant colony optimization

# %%
best_params = AntColonyOptimization(
    JoinedEvaluator,
    joined=[ClockEvaluator, FreqEvaluator],
).optimize_parameters(20, 100)

evaluation = EvaluationBase(**best_params)
# here we can't print the score because it's caclulated based on 2 evaluators
print(evaluation.get_params())
evaluation.simulate(out='./ant_joined.png', algo='ant colony')
# Out:
# [0] Update best with 2.05142
# [1] Update best with 2.21778
# [2] Update best with 2.24279
# [3] Update best with 2.27354
# [5] Update best with 2.27832
# [6] Update best with 2.46634
# [14] Update best with 2.52969
# [16] Update best with 2.54349
# [34] Update best with 2.56798
# [69] Update best with 2.62827
# {'alpha1': 36.92077169637427, 'alpha2': 50.0, 'alpha3': 34.33160100961173, 'alpha4': 48.18910973694262, 'delta1': 0.001, 'delta2': 0.07093969360334396, 'Kd': 9.915550788539253, 'n': 5.0}
